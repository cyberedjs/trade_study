# %% [markdown]
# # 1.NUMPY
#
# 1. 행렬연산을 빠르게
# 2. 데이터 생성, 수정 등등

# %% [markdown]
# ## 1.1 Array
# - array
# - ndim, shape
# - reshape
# - masking
# - arange
# - astype

# %%
import numpy as np

arr = np.array([[1, 2, 3], [4, 5, 6]])
arr.ndim
# Out:
# 2
