# %%
# !git clone https://github.com/Hephyrius/binance_futures_bot
# Out:
# Cloning into 'binance_futures_bot'...
# remote: Enumerating objects: 198, done.
# remote: Counting objects: 100% (198/198), done.
# remote: Compressing objects: 100% (137/137), done.
# remote: Total 198 (delta 103), reused 125 (delta 47), pack-reused 0
# Receiving objects: 100% (198/198), 123.52 KiB | 17.64 MiB/s, done.
# Resolving deltas: 100% (103/103), done.

# %%
# !cd binance_futures_bot/

# %%
# !pip install -r binance_futures_bot/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 14.9 MB 83 kB/s
# ...
#      |████████████████████████████████| 9.5 MB 46.6 MB/s
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...

# %%
# !python3 -m pip install git+https://github.com/Binance-docs/Binance_Futures_python.git
# Out:
# ...
#   Cloning https://github.com/Binance-docs/Binance_Futures_python.git to /tmp/pip-req-build-jllpi4ak
#   Running command git clone -q https://github.com/Binance-docs/Binance_Futures_python.git /tmp/pip-req-build-jllpi4ak
# ...
#      |████████████████████████████████| 59 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 68 kB 5.0 MB/s
# ...
#   Created wheel for binance-futures: filename=binance_futures-1.1.0-py3-none-any.whl size=99796 sha256=9f949d4254b59193b8c6bd2dc6b642c7e5931ecb997901c63a1099ccb33313bf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rfatcc2u/wheels/8e/d7/89/1b95165ca89880d149817249426a3e7f2aeeaf5004ac71c0a0
# Successfully built binance-futures
# ...
#   Attempting uninstall: tzlocal
#     Found existing installation: tzlocal 1.5.1
#     Uninstalling tzlocal-1.5.1:
#       Successfully uninstalled tzlocal-1.5.1
# ...

# %%
! vim binance_futures_bot/settings.json
# Out:
# /bin/bash: vim: command not found

# %%
# !python3 binance_futures_bot/bot.py
# Out:
# Traceback (most recent call last):
#   File "binance_futures_bot/bot.py", line 7, in <module>
#     client = bf.init_client()
#   File "/content/binance_futures_bot/bot_functions.py", line 28, in init_client
#     client = RequestClient(api_key=cfg.getPublicKey(), secret_key=cfg.getPrivateKey(), url=cfg.getBotSettings().api_url)
#   File "/content/binance_futures_bot/config.py", line 11, in getPublicKey
#     return getAPIKeys().api_key
#   File "/content/binance_futures_bot/config.py", line 8, in getAPIKeys
#     return json.load(open ("keys.json", "r"), object_hook=lambda d: SimpleNamespace(**d)) #convert array to object
# FileNotFoundError: [Errno 2] No such file or directory: 'keys.json'

# %%
# %cd binance_futures_bot
# Out:
# /content/binance_futures_bot

# %%
# !python3 bot.py
# Out:
# Bot Starting
# ====== Request ======
# ...
# header:{'client_SDK_Version': 'binance_futures-1.0.1-py3.7', 'Content-Type': 'application/json', 'X-MBX-APIKEY': 'ncaGKCQNu9KS8kEwF3Jri37YjsOkKCfLGiKZcq87iThEU3QZIWdxOyeQLUvOCPpG'}
# host:https://fapi.binance.com/
# json_parser:None
# method:POST
# post_body:{}
# url:/fapi/v1/order?symbol=ALICEUSDT&side=BUY&type=MARKET&quantity=64.5&positionSide=BOTH&recvWindow=60000&timestamp=1627111807413&signature=2a5a01aa7a67203292604eb7b8aa1b10038812368003327238c647bcf3d185bc
# ...
# {"orderId":811079761,"symbol":"ALICEUSDT","status":"NEW","clientOrderId":"Zfj9X2hGCUdMkVq0n1VJRS","price":"0","avgPrice":"0.0000","origQty":"64.5","executedQty":"0","cumQty":"0","cumQuote":"0","timeInForce":"GTC","type":"MARKET","reduceOnly":false,"closePosition":false,"side":"BUY","positionSide":"BOTH","stopPrice":"0","workingType":"CONTRACT_PRICE","priceProtect":false,"origType":"MARKET","updateTime":1627111808509}
# BUY: 64.5 $7.671 using x5 leverage
# ...
