# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/Colab Notebooks/.git/

# %%
# !git config --global user.email "joonsuheojs@gmail.com"
# !git config --global user.name "cyberedjs"

# %%
# !git add .

# %%
# !git commit -m "Uploading all the works"
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git remote add origin https://{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}@github.com/cyberedjs/trade_study.git
