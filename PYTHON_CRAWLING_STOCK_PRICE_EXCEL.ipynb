# %%
import requests
from bs4 import BeautifulSoup

header = {'User-Agent' : 'Mozila/2.0'}

#종목 코드 리스트

codes = ['005930', '000660', '035720']

for code in codes:
  url = f"https://finance.naver.com/item/sise.naver?code={code}"
  response = requests.get(url, headers = header)
  html = response.text
  soup = BeautifulSoup(html, 'html.parser')
  current = soup.select_one("#_nowVal").text
  price = current.replace(',', '')
  print(price)
# Out:
# 66500
# 106000
# 81700

# %%
#엑셀 다루기
# !pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import openpyxl

# 1) 엑셀 만들기
wb = openpyxl.Workbook()

# 2) 엑셀 워크시트 만들기
ws = wb.create_sheet('오징어게임')

# 3) 데이터 추가하기
ws['A1'] = '참가번호'
ws['B1'] = '성명'

ws['A2'] = 1
ws['B2'] = '오일남'

# 4) 엑셀 저장하기
wb.save(r'/content/drive/MyDrive/Colab Notebooks/DATA/참가자_data.xlsx')

# %%
import openpyxl

fpath = r'/content/drive/MyDrive/Colab Notebooks/DATA/참가자_data.xlsx'

# 1) 엑셀 불러오기
wb = openpyxl.load_workbook(fpath)

# 2) 엑셀 시트선택

ws = wb['오징어게임']

# 3) 데이터 수정하기
ws['A3'] = 456
ws['B3'] = "성기훈"

# 4) 엑셀 저장하기
wb.save(fpath)
