# %%
#Getting data live via database engine / already running in aws

# %%
# !pip install streamlit

# %%
# !pip install Jinja2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import streamlit as st
import pandas as pd
import datetime as dt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-510adaddc58b> in <module>()
# ----> 1 import streamlit as st
#       2 import pandas as pd
#       3 import datetime as dt
#
# /usr/local/lib/python3.7/dist-packages/streamlit/__init__.py in <module>()
#      68 from streamlit import source_util as _source_util
#      69 from streamlit import string_util as _string_util
# ---> 70 from streamlit.delta_generator import DeltaGenerator as _DeltaGenerator
#      71 from streamlit.scriptrunner import (
#      72     add_script_run_ctx as _add_script_run_ctx,
#
# /usr/local/lib/python3.7/dist-packages/streamlit/delta_generator.py in <module>()
#      34
#      35 import streamlit as st
# ---> 36 from streamlit import cursor, caching
#      37 from streamlit import legacy_caching
#      38 from streamlit import type_util
#
# ...
