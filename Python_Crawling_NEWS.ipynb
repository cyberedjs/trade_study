# %%
# !pip install beautifulSoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get("https://www.naver.com")
html = response.text
soup = BeautifulSoup(html, 'html.parser')
word = soup.select_one("#NM_set_home_btn")
print(word.text)
# Out:
# 네이버를 시작페이지로

# %%
import requests
from bs4 import BeautifulSoup

header = {'User-agent' : 'Mozila/2.0'}

response = requests.get("https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=101", headers = header)
html = response.text
soup = BeautifulSoup(html, 'html.parser')

title = soup.select_one(".cluster_text_headline")
print(title.text.strip())
# Out:
# 최근 5년여간 금융권 임직원 횡령액 1000여억원…환수율 11.6% 불과

# %%
import requests
from bs4 import BeautifulSoup

header = {'User-agent' : 'Mozila/2.0'}

response = requests.get("https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=101", headers = header)
html = response.text
soup = BeautifulSoup(html, 'html.parser')

titles = soup.select(".cluster_text_headline")
for title in titles:
  print(title.text.strip())
# Out:
# 롯데건설, 서울 돈암6구역 주택재개발 정비사업 수주
# 롯데건설, 서울 성북구 '돈암6구역' 재개발 수주
# 롯데건설, 2656억 규모 돈암6구역 재개발 사업 수주
# 롯데건설, 돈암6구역 재개발 수주…"올해 정비사업 수주 1.7조"
# 산업기술진흥원, 소부장 특화단지내 핵심기술 테스트베드 구축
# 산업기술진흥원, 반도체 핵심기술 국산화 지원 강화
# KIAT, 반도체 핵심 기술 국산화 지원
# KIAT, 반도체 테스트베드로 핵심기술 국산화 지원
# 신학철 LG화학 부회장, 獨서 ESG 혁신 기술 이끌 인재 찾는다
# 신학철 LG화학 부회장, 독일서 ESG 혁신 이끌 인재 찾는다
# 신학철 LG화학 부회장, 獨서 ESG 혁신기술 이끌 인재 찾는다
# 신학철 LG화학 부회장, 獨서 ESG 혁신 기술 이끌 인재 찾는다
# 6월 첫째주 9163가구 분양…7주째 1만 가구 밑돌아
# 선거 끝났다…전국 곳곳서 분양 대전 돌입[부동산360]
# 기아, 통합모바일 고객 앱 '마이기아' 리뉴얼 출시
# 기아, 통합 모바일 고객 앱 '기아 빅'→'마이기아' 리뉴얼
# LH, 주거사회 서비스 사업 공모… “주거취약 문제 해결”
# LH, 주거사회 서비스 사업 공모 실시…주거사회 문제 해결 목적
# 최근 5년여간 금융권 임직원 1000여억원 빼돌려…환수율 11.6%
# 우리은행 5년간 직원 9명, 633억원 가로채…환수율 1.3%[금융권 횡령]
# 신분당선 ‘강남~신사’ 오늘 개통… 광교→신사 42분
# 신림선 도시철도 개통…신분당선 강남~신사 연장
# 해외여행 예약률 230% ↑…일본 패키지, 2시간만에 완판
# 해외여행 예약 230%↑…일본 패키지는 2시간만에 완판
# 수출 1위 김, 일본에 650억 규모 수출계약…전년比 11%↑
# 올해 일본에 한국김 650억원어치 수출
# 우크라發 수입 육류가격 1년새 39% ‘껑충’…소고기 56%↑·돼지고기 14%↑
# 수입 육류가격지수 1년 새 39% 올라…소고기 56%↑
# ...

# %%
#class는 '.', id는 '#'

import requests
from bs4 import BeautifulSoup

header = {'User-Agent' : 'Mozila/2.0'}

response = requests.get("https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90", headers=header)
html = response.text
soup = BeautifulSoup(html, 'html.parser')

links = soup.select('.news_tit')
for link in links:
  title = link.text
  url = link.attrs['href'] #href의 속성값을 가져온다
  print(title, url)
# Out:
# 삼성전자, '비스포크 인피니트 라인' 인덕션 출시 https://zdnet.co.kr/view/?no=20220529094518
# 삼성 기업평판, 미국 내 6위…전년보다 25계단 '껑충" http://www.newsis.com/view/?id=NISX20220529_0001889331&cID=13001&pID=13000
# "삼성도 별수 없다"…4년만에 상반기 '경영전략회의' 나선 이유 http://www.inews24.com/view/1485079
# 삼성전자, 이미지센서 세계 1위 소니 추격…점유율 격차 24.5%→15.9% https://biz.chosun.com/it-science/ict/2022/05/29/T7LREE4OVRCOHCGAUTGRGH5Y5Q/?utm_source=naver&utm_medium=original&utm_campaign=biz
# 삼성전자, 美테일러 파운드리 공장 건설 본격화…내달 착공 예상 https://www.yna.co.kr/view/AKR20220527074400003?input=1195m
# 삼성전자, '비스포크 인피니트 라인' 인덕션 출시 http://www.digitaltoday.co.kr/news/articleView.html?idxno=447458
# “中 때문에 손해는 못참지” 삼성D, 결국 이 사업 접는다[비즈360] http://news.heraldcorp.com/view.php?ud=20220527000681
# 1분기 전 세계 팔린 TV 2대 중 1대는 韓기업…"역시 삼성·LG" https://view.asiae.co.kr/article/2022052713185686636
# "여기만 가면 '한국폰 무덤'"…희망 본 삼성전자, 재기 노린다 http://www.inews24.com/view/1484944
# '바이든 삼성 방문'에 떠들썩…조용히 '반도체 칼' 가는 日 [강경주의 IT카페... https://www.hankyung.com/it/article/202205276099g

# %%
#검색어 입력 받아서 크롤링하기

import requests
from bs4 import BeautifulSoup

header = {'User-Agent' : 'Mozila/2.0'}

keyword = input("검색어를 입력해주세요>>>")
response = requests.get("https://search.naver.com/search.naver?where=news&sm=tab_jum&query=" + keyword, headers=header)
html = response.text
soup = BeautifulSoup(html, 'html.parser')

links = soup.select('.news_tit')
for link in links:
  title = link.text
  url = link.attrs['href'] #href의 속성값을 가져온다
  print(title, url)
# Out:
# 검색어를 입력해주세요>>>코딩
# 청소년 코딩 통해 사회 현안 해결 http://www.koit.co.kr/news/articleView.html?idxno=97691
# 코딩 대회 수상 못해도…학생부전형으로 '소프트웨어학과' 간다 http://www.newspim.com/news/view/20220527001087
# 에듀 TV, 다음세대 코딩 교육 교재 설명회 개최 http://www.cts.tv/news/view?ncate=THMNWS01&dpid=290291
# "꿈을 찾고 행복을 이루는 진로교육"…충청북도진로교육원 https://www.nocutnews.co.kr/news/5763608
# 어린이 코딩학원 '코리아코딩아카데미', 국영수코 시대 체계적인 코딩 교육과... http://www.it-b.co.kr/news/articleView.html?idxno=59929
# [ESG 브랜드 대상]렌쥴리에듀테인먼트 http://www.etnews.com/20220527000061
# 직장인이 코딩 배워보니... "험난한 '주경야독'의 길...'끈기'는 필수" https://www.mk.co.kr/economy/view/2022/445722
# [기고] 목공 + CNC + 코딩 = 코딩목공 수업 http://www.imwood.co.kr/news/articleView.html?idxno=27517
# MS '개발자 대회' 빌드 개최…전문가·일반인 'AI 코딩' 돕는다 https://www.news1.kr/articles/?4691456
# 10대 위한 코딩·철학 등 비교과 교육 '스쿨닷츠', 시드투자 유치 http://news.mt.co.kr/mtview.php?no=2022052408444457945

# %%
#검색어 입력 받아서 크롤링하기 + pyautogui
import pyautogui
import requests
from bs4 import BeautifulSoup

header = {'User-Agent' : 'Mozila/2.0'}

keyword = pyautogui.prompt("검색어를 입력해주세요>>>")
response = requests.get(f"https://search.naver.com/search.naver?where=news&sm=tab_jum&query={keyword}", headers=header)
html = response.text
soup = BeautifulSoup(html, 'html.parser')

links = soup.select('.news_tit')
for link in links:
  title = link.text
  url = link.attrs['href'] #href의 속성값을 가져온다
  print(title, url)

# %%
import requests
from bs4 import BeautifulSoup

header = {'User-Agent' : 'Mozila/2.0'}

keyword = pyautogui.prompt("검색어를 입력해주세요>>>")
lastpage = pyautogui.prompt("마지막 페이지 번호를 입력해주세요>>>")
pageNum = 1
for i in range(1, int(lastpage * 10), 10):
  print(f"{pageNum}페이지 입니다.=================================")
  response = requests.get(f"https://search.naver.com/search.naver?where=news&sm=tab_jum&query={keyword}&start={i}", headers=header)
  html = response.text
  soup = BeautifulSoup(html, 'html.parser')
  links = soup.select('.news_tit')
  for link in links:
    title = link.text
    url = link.attrs['href'] #href의 속성값을 가져온다
    print(title, url)
  pageNum = pageNum + 1
